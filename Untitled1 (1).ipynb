# %%
name="muthu"
age=19
CGPA=8.5
placed=True
print("student name:" , name)
print("student age:" , age)
print("student CGPA:" , CGPA)
print("student placed:" , placed)
print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))
# Out:
# student name: muthu
# student age: 19
# student CGPA: 8.5
# student placed: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name=["muthu","kavi","bala"]
name.append("mukii")
marks=[100,80,90]
print(name[0])
print(name)
print(marks[0])
print(name[1])
print(marks[1])
print(name[2])
print(len(name))
print(len(marks))
# Out:
# muthu
# ['muthu', 'kavi', 'bala', 'mukii']
# 100
# kavi
# 80
# bala
# 4
# 3
